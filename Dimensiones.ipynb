# %% [markdown]
# Dimensiones

# %%
import numpy as np

# %%
nuevo_elemento_aleatorio = np.random.randint(1,20,12)
nuevo_elemento_aleatorio
# Out:
# array([17, 15, 16, 15, 17,  5, 14, 14,  2, 16, 17,  1])

# %%
np.shape(nuevo_elemento_aleatorio)
# Out:
# (8,)

# %%
matriz = nuevo_elemento_aleatorio.reshape(4,3)
matriz
# Out:
# array([[17, 15, 16],
#        [15, 17,  5],
#        [14, 14,  2],
#        [16, 17,  1]])

# %%
np.shape(matriz)
# Out:
# (4, 3)
